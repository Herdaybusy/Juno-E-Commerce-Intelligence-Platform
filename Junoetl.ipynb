# %% [markdown]
# Installing Neccessary libraries

# %%
# !pip install requests sqlalchemy beautifulsoup4 python-dotenv psycopg2

# %% [markdown]
# Importing the libraries

# %%
from sqlalchemy import create_engine, text
from bs4 import BeautifulSoup
import pandas as pd
import requests
from dotenv import load_dotenv
import os 
import re

# %%
from sqlalchemy import create_engine, text

# %% [markdown]
# Test the Response Status

# %%
url = 'https://www.ebay.co.uk/'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!--vertlandweb#s0-1-0--><!DOCTYPE html><!--[if IE 9 ]>    <html class="ie9"> <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html lang=en><!--<![endif]--><head><!--vertlandweb^s0-1-0-4 s0-1-0 4--><!--vertlandweb/--><!--vertlandweb^s0-1-0-5 s0-1-0 5--><link rel="dns-prefetch" href="//ir.ebaystatic.com"><link rel="dns-prefetch" href="//secureir.ebaystatic.com"><link rel="dns-prefetch" href="//i.ebayimg.com"><link rel="dns-prefetch" href="//rover.ebay.com"><script>$ssgST=new Date().getTime();</script><!--vertlandweb/--><link rel=preload as=image href=https://ir.ebaystatic.com/pictures/aw/pics/s_1x2.gif crossorigin><meta charset=utf-8><link rel=icon href=https://pages.ebay.com/favicon.ico><meta name=viewport content="width=device-width, initial-scale=1, user-scalable=yes, minimum-scale=1"><meta http-equiv=X-UA-Compatible content=IE=edge><link href=https://srv.uk.ebayrtm.com rel=preconnect><noscript><style>\n        .js-only {\n          display: none !important;\n        }\n      </style></
# ...

# %% [markdown]
# ### Integrating requests with beautifulsoup

# %%
url = 'https://www.ebay.co.uk/'
response = requests.get(url)

soup = BeautifulSoup(response.text, "lxml")
soup
# Out:
# <!--vertlandweb#s0-1-0--><!DOCTYPE html>
# <!--[if IE 9 ]>    <html class="ie9"> <![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html lang="en"><!--<![endif]--><head><!--vertlandweb^s0-1-0-4 s0-1-0 4--><!--vertlandweb/--><!--vertlandweb^s0-1-0-5 s0-1-0 5--><link href="//ir.ebaystatic.com" rel="dns-prefetch"/><link href="//secureir.ebaystatic.com" rel="dns-prefetch"/><link href="//i.ebayimg.com" rel="dns-prefetch"/><link href="//rover.ebay.com" rel="dns-prefetch"/><script>$ssgST=new Date().getTime();</script><!--vertlandweb/--><link as="image" crossorigin="" href="https://ir.ebaystatic.com/pictures/aw/pics/s_1x2.gif" rel="preload"/><meta charset="utf-8"/><link href="https://pages.ebay.com/favicon.ico" rel="icon"/><meta content="width=device-width, initial-scale=1, user-scalable=yes, minimum-scale=1" name="viewport"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><link href="https://srv.uk.ebayrtm.com" rel="preconnect"/><noscript><style>
#         .js-only {
# ...

# %% [markdown]
# Data Extraction

# %%
url = 'https://www.ebay.co.uk/sch/i.html?_nkw=laptops&_sacat=0&_from=R40&_trksid=p2334524.m570.l1313&rt=nc&_odkw=generator&_osacat=0&LH_All=1'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'lxml')

# %%
# PRODUCTS EXTRACTION 
names = soup.find_all('span', role='heading' )

# PRODUCT NAMES
product_names = []
for name in names[2:]:
    product_names.append(name.get_text(strip=True))

# %%
product_names
# Out:
# ['Laptop HP Windows 11 CORE i5 GEN 6 - 12TH GEN 32GB RAM 1TB SSD WEBCAM WIFI',
#  'FAST CHEAP CORE i5 LAPTOP 1TB SSD 32GB RAM WARRANTY FREE WINDOWS 11 UPGRADE',
#  'FAST CHEAP TOP BRAND INTEL CORE i5 8TH GEN 16GB RAM 480GB SSD WINDOWS 11 LAPTOP',
#  'CUSTOM FAST CHEAP LAPTOP Intel Core i3/i5 - Windows 10 - WiFi',
#  'SUPER FAST WINDOWS 11 CHEAP LAPTOP INTEL CORE I5 4/8/16GB RAM 1TB HDD SSD WEBCAM',
#  'Lenovo MIIX 320-10ICR 2in1 tablet - Intel Atom x5 Z8350 4GB RAM - 64GB (GRADE A)',
#  'CHEAP FAST Laptop DELL Quad Core 2.6GHZ Windows 10 SSD 4K HDMI WIFI WEBCAM',
#  'Stone StoneBook Mini M10A 11.6" Laptop 120GB SSD 4GB RAM CHEAP COMPACT + PSU #1i',
#  'Laptop HP Windows 11 CORE i5 GEN 6 - 12TH GEN 32GB RAM 1TB SSD WEBCAM WIFI',
#  'FAST CHEAP CORE i5 LAPTOP 1TB SSD 32GB RAM WARRANTY FREE WINDOWS 11 UPGRADE',
#  'Lenovo ThinkPad T480 i5-8250U up to 64GB Ram up to 2TB SSD FHD Windows Laptop',
#  'Dell Latitude 7420 i5-1145G7 11th Gen 16GB Ram 256GB SSD FHD Windows 11 Laptop',
# ...

# %%
len(product_names)
# Out:
# 84

# %%
# PRICES EXTRACTION 
current_price =  []
prices = soup.find_all('span', class_='s-item__price' ) #CURRENT PRICE
for price in prices:
    current_price.append(price.get_text(strip=True))
len(current_price)
# Out:
# 87

# %%
current_price
# Out:
# ['$20.00',
#  '$20.00',
#  '£189.99to£420.00',
#  '£129.99to£299.99',
#  '£129.99to£254.99',
#  '£94.99to£134.99',
#  '£99.99to£219.99',
#  '£35.99',
#  '£89.99',
#  '£29.98',
#  '£199.99',
#  '£149.99',
#  '£219.99',
#  '£309.99',
#  '£86.99',
#  '£144.95',
#  '£248.99',
#  '£159.99',
#  '£74.99',
#  '£49.99',
#  '£119.99',
#  '£29.95',
#  '£109.99to£329.99',
#  '£209.99',
#  '£99.99to£119.99',
#  '£99.99',
#  '£54.99',
#  '£67.96to£84.96',
#  '£79.00',
#  '£219.99to£504.99',
#  '£134.99',
#  '£119.99to£169.99',
#  '£139.00to£234.00',
#  '£14.99',
#  '£52.71',
#  '£104.72',
#  '£363.72',
#  '£69.99',
#  '£63.12',
#  '£219.00',
#  '£151.10',
#  '£109.99',
#  '£229.00',
#  '£159.99to£489.99',
#  '£9.99',
#  '£71.99to£79.99',
#  '£130.61',
#  '£120.31',
#  '£49.99',
#  '£118.99',
#  '£199.99to£589.99',
#  '£229.99',
#  '£70.00',
#  '£99.52',
#  '£99.52',
#  '£120.00',
#  '£104.72',
#  '£65.00',
#  '£73.52',
#  '£69.95to£89.95',
#  '£63.12',
#  '£144.76',
#  '£129.99',
#  '£98.01',
# ...

# %%
len(product_names), len(current_price)
# Out:
# (84, 87)

# %%
# FORMER PRICE
former_price = [] 

prices = soup.find_all('span', class_='STRIKETHROUGH' ) #FORMER PRICE
for price in prices:
    former_price.append(price.get_text(strip= True))

# %%
former_price
# Out:
# ['£849.95',
#  '£749.95',
#  '£59.99',
#  '£399.95',
#  '£849.95',
#  '£258.99',
#  '£79.95',
#  '£439.99',
#  '£400.00',
#  '£799.95',
#  '£99.99',
#  '£449.99',
#  '£649.99',
#  '£999.99']

# %%
len(product_names), len(current_price) ,len(former_price)
# Out:
# (84, 87, 14)

# %%
# ITEMS SOLD
all_items_solds = [] 

items = soup.find_all('span', class_="s-item__dynamic s-item__quantitySold" ) #ITEMS SOLD
for item in items:
    all_items_solds.append(item.get_text(strip= True))

# %%
len(product_names), len(current_price) ,len(former_price), len(all_items_solds)
# Out:
# (84, 87, 14, 27)

# %%
all_items_solds
# Out:
# ['9+ sold',
#  '103+ sold',
#  '562 sold',
#  '954 sold',
#  '21+ sold',
#  '210+ sold',
#  '548+ sold',
#  '126 sold',
#  '12+ sold',
#  '254+ sold',
#  '132 sold',
#  '14 sold',
#  '525 sold',
#  '224 sold',
#  '548+ sold',
#  '14 sold',
#  '41+ sold',
#  '56 sold',
#  '32 sold',
#  '949 sold',
#  '31 sold',
#  '50 sold',
#  '254+ sold',
#  '31 sold',
#  '18 sold',
#  '131 sold',
#  '69 sold']

# %%
# SELLER INFO
all_seller_info = [] 

items_seller = soup.find_all('span', class_="s-item__seller-info-text" ) #SELLER INFO 
for items in items_seller:
    all_seller_info.append(items.get_text(strip= True))

# %%
all_seller_info
# Out:
# ['birmingham-av (12,057) 98.8%',
#  'birmingham-av (12,057) 98.8%',
#  'good-cheap-laptops (9,794) 97.1%',
#  'giga-refurb (8,503) 98.4%',
#  'gadgetsxpress7 (4,550) 99.7%',
#  'mobstars (23,014) 98.9%',
#  'birmingham-av (12,057) 98.8%',
#  'kel-tel (30,178) 99.4%',
#  'birmingham-av (12,057) 98.8%',
#  'birmingham-av (12,057) 98.8%',
#  'newandusedlaptops4u (77,525) 99.6%',
#  'newandusedlaptops4u (77,525) 99.6%',
#  'resycit (6,563) 99.3%',
#  'venoscorp (19,963) 98.4%',
#  'meshshop (4,286) 100%',
#  'giga-refurb (8,503) 98.4%',
#  'quattro_outlet (29) 100%',
#  'talostrades (0) 0%',
#  'ecolaptop (14,365) 99.4%',
#  'pcs4u-uk (2,556) 99.5%',
#  'birmingham-av (12,057) 98.8%',
#  'newandusedlaptops4u (77,525) 99.6%',
#  'giga-refurb (8,503) 98.4%',
#  'recycly.tech (2,341) 98.3%',
#  'yellowape (5,270) 98.8%',
#  'priceholes-com (9,325) 99.6%',
#  'orioncomputersuk (750) 99.6%',
#  'newandusedlaptops4u (77,525) 99.6%',
#  'laptop-top-deals (8,125) 99.3%',
# ...

# %%
# BRAND CATEGORY
brand_category = [] 

brands= soup.find_all('span', class_="SECONDARY_INFO" ) # BRANDS
for brand in brands:
    brand_category.append(brand.get_text(strip= True))

# %%
len(product_names), len(current_price) ,len(former_price), len(all_items_solds), len(all_seller_info), len(brand_category)
# Out:
# (84, 87, 14, 27, 84, 78)

# %%
brand_category
# Out:
# ['Brand New',
#  'Brand New',
#  'Good - Refurbished',
#  'Good - Refurbished',
#  'Very Good - Refurbished',
#  'Very Good - Refurbished',
#  'Good - Refurbished',
#  'Very Good - Refurbished',
#  'Good - Refurbished',
#  'Pre-owned',
#  'Pre-owned',
#  'Pre-owned',
#  'Very Good - Refurbished',
#  'Pre-owned',
#  'Good - Refurbished',
#  'Very Good - Refurbished',
#  'Very Good - Refurbished',
#  'Good - Refurbished',
#  'Pre-owned',
#  'Pre-owned',
#  'Good - Refurbished',
#  'Very Good - Refurbished',
#  'Pre-owned',
#  'Very Good - Refurbished',
#  'Pre-owned',
#  'Pre-owned',
#  'Excellent - Refurbished',
#  'Pre-owned',
#  'Excellent - Refurbished',
#  'Brand new',
#  'Brand new',
#  'Brand new',
#  'Good - Refurbished',
#  'Pre-owned',
#  'Good - Refurbished',
#  'Opened – never used',
#  'Good - Refurbished',
#  'Pre-owned',
#  'Pre-owned',
#  'Pre-owned',
#  'Good - Refurbished',
#  'Pre-owned',
#  'Pre-owned',
#  'Pre-owned',
#  'Pre-owned',
#  'Pre-owned',
# ...

# %%
len(product_names), len(current_price) ,len(former_price), len(all_items_solds), len(brand_category)
# Out:
# (84, 87, 14, 27, 78)

# %%
data = {
    'title' : product_names,
    'current_price' : current_price,
    'former_price' : former_price,
    'all_items_solds' : all_items_solds,
    'brand_category': brand_category,
    'all_seller_info' : all_seller_info
}

laptop_df = pd.DataFrame.from_dict(data, orient= 'index')

# %%
laptop_df.head()
# Out:
#                                                               0     \
# title            Laptop HP Windows 11 CORE i5 GEN 6 - 12TH GEN ...
# current_price                                               $20.00
# former_price                                               £849.95
# all_items_solds                                            9+ sold
# brand_category                                           Brand New
#
#                                                               1     \
# title            FAST CHEAP CORE i5 LAPTOP 1TB SSD 32GB RAM WAR...
# current_price                                               $20.00
# former_price                                               £749.95
# all_items_solds                                          103+ sold
# brand_category                                           Brand New
#
#                                                               2     \
# title            FAST CHEAP TOP BRAND INTEL CORE i5 8TH GEN 16G...
# ...

# %%
laptop_df = laptop_df.transpose()
laptop_df.head()
# Out:
#                                                               0     \
# title            Laptop HP Windows 11 CORE i5 GEN 6 - 12TH GEN ...
# current_price                                               $20.00
# former_price                                               £849.95
# all_items_solds                                            9+ sold
# brand_category                                           Brand New
#
#                                                               1     \
# title            FAST CHEAP CORE i5 LAPTOP 1TB SSD 32GB RAM WAR...
# current_price                                               $20.00
# former_price                                               £749.95
# all_items_solds                                          103+ sold
# brand_category                                           Brand New
#
#                                                               2     \
# title            FAST CHEAP TOP BRAND INTEL CORE i5 8TH GEN 16G...
# ...

# %%
# FOR ALL PAGES
pages = [x for x in range(1, 20)]

product_names = []
current_price =  []
former_price = []
all_items_solds = [] 
all_seller_info = [] 
brand_category = [] 

for page in pages:
    url = f'https://www.ebay.co.uk/sch/i.html?_nkw=laptops&_sacat=0&_from=R40&_ipg=60&rt=nc&_pgn={page}'
    response = requests.get(url)

    soup = BeautifulSoup(response.text, 'lxml')
    
    # PRODUCT NAMES
    names = soup.find_all('span', role='heading' ) # PRODUCT NAME
    for name in names[2:]:
        product_names.append(name.get_text(strip=True))
    
    # PRICES EXTRACTION 
    prices = soup.find_all('span', class_='s-item__price' ) #CURRENT PRICE
    for price in prices:
        current_price.append(price.get_text(strip=True))

    # FORMER PRICE
    prices = soup.find_all('span', class_='STRIKETHROUGH' ) #FORMER PRICE
    for price in prices:
        former_price.append(price.get_text(strip= True))
    
    # ITEMS SOLD
    items = soup.find_all('span', class_="s-item__dynamic s-item__quantitySold" ) #ITEMS SOLD
    for item in items:
        all_items_solds.append(item.get_text(strip= True))
    
    # BRAND CATEGORY
    brands= soup.find_all('span', class_="SECONDARY_INFO" ) #ITEMS SOLD
    for brand in brands:
        brand_category.append(brand.get_text(strip= True))
    
    # SELLER INFO
    items_seller = soup.find_all('span', class_="s-item__seller-info-text" ) #SELLER INFO
    for items in items_seller:
        all_seller_info.append(items.get_text(strip= True))
    
data = {
'title' : product_names,
'current_price' : current_price,
'former_price' : former_price,
'all_items_solds' : all_items_solds,
'brand_category': brand_category,
'all_seller_info' : all_seller_info
}

laptop_df = pd.DataFrame.from_dict(data, orient= 'index')
laptop_df = laptop_df.transpose()
laptop_df.head()
# Out:
#                                                title     current_price  \
# 0  FAST CHEAP TOP BRAND INTEL CORE i5 8TH GEN 16G...            $20.00
# 1  Laptop HP Windows 11 CORE i5 GEN 6 - 12TH GEN ...            $20.00
# 2  FAST CHEAP CORE i5 LAPTOP 1TB SSD 32GB RAM WAR...  £129.99to£254.99
# 3  Lenovo ThinkPad T480 i5-8250U up to 64GB Ram u...  £189.99to£420.00
# 4  SUPER FAST WINDOWS 11 CHEAP LAPTOP INTEL CORE ...  £129.99to£299.99
#
#   former_price all_items_solds           brand_category  \
# 0    £1,049.95       171+ sold                Brand New
# 1      £649.95        30+ sold                Brand New
# 2      £439.99       548+ sold  Very Good - Refurbished
# 3      £399.95       103+ sold       Good - Refurbished
# 4       £59.99        954 sold       Good - Refurbished
#
#                       all_seller_info
# 0    good-cheap-laptops (9,794) 97.1%
# 1        birmingham-av (12,057) 98.8%
# 2        birmingham-av (12,057) 98.8%
# 3  newandusedlaptops4u (77,525) 99.6%
# ...

# %%
laptop_df.to_csv('Laptop Record.csv', index=False)

# %% [markdown]
#  Data Transformation

# %%
# COPY DATA TO KEEP THE RAW DATA
df = laptop_df.copy()

# %%
# CHECKING THE DATA INFO
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1511 entries, 0 to 1510
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1452 non-null   object
#  1   current_price    1511 non-null   object
#  2   former_price     244 non-null    object
#  3   all_items_solds  202 non-null    object
#  4   brand_category   1482 non-null   object
#  5   all_seller_info  1452 non-null   object
# dtypes: object(6)
# memory usage: 71.0+ KB

# %%
df.fillna({
    'title' : 'Unknown',
    'former_price': 0.0,
    'all_items_solds' : 'Unknown',
    'brand_category' : 'Unknown',
    'all_seller_info' : 'Unknown'
}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1511 entries, 0 to 1510
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1511 non-null   object
#  1   current_price    1511 non-null   object
#  2   former_price     1511 non-null   object
#  3   all_items_solds  1511 non-null   object
#  4   brand_category   1511 non-null   object
#  5   all_seller_info  1511 non-null   object
# dtypes: object(6)
# memory usage: 71.0+ KB

# %%
df.head()
# Out:
#                                                title     current_price  \
# 0  Laptop HP Windows 11 CORE i5 GEN 6 - 12TH GEN ...            $20.00
# 1  FAST CHEAP CORE i5 LAPTOP 1TB SSD 32GB RAM WAR...            $20.00
# 2  FAST CHEAP TOP BRAND INTEL CORE i5 8TH GEN 16G...  £189.99to£420.00
# 3  CUSTOM FAST CHEAP LAPTOP Intel Core i3/i5 - Wi...  £129.99to£299.99
# 4  SUPER FAST WINDOWS 11 CHEAP LAPTOP INTEL CORE ...  £129.99to£254.99
#
#   former_price all_items_solds           brand_category  \
# 0      £849.95         9+ sold                Brand New
# 1      £749.95       103+ sold                Brand New
# 2       £59.99        562 sold       Good - Refurbished
# 3      £399.95        954 sold       Good - Refurbished
# 4      £849.95        21+ sold  Very Good - Refurbished
#
#                     all_seller_info
# 0      birmingham-av (12,057) 98.8%
# 1      birmingham-av (12,057) 98.8%
# 2  good-cheap-laptops (9,794) 97.1%
# 3         giga-refurb (8,503) 98.4%
# ...

# %% [markdown]
# LOADING DATA TO DATABASE

# %%
# ACCESSING THE DATABASE
load_dotenv(override=True)
db_user = os.getenv('DB_USER')
db_name = os.getenv('DB_NAME')
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT')
db_password = os.getenv('DB_PASSWORD')

# %%
db_name
# Out:
# 'JUNO_ECOMMERCE'

# %%
database_url = f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"
engine = create_engine(database_url)
display('Connected successfully')
# Out:
# 'Connected successfully'

# %%
laptop_records = df.copy()
laptop_records.to_sql('Laptop_Records',engine, if_exists='replace', index=False)
# Out:
# 511
